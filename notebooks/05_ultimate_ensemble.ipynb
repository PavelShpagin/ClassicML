# %% [markdown]
# # Ultimate Ensemble: Targeting 0.60+ Score
#
# ## Strategy
#
# 1. **Zero Prediction**: Binary classifier + zero guard
# 2. **Rich Features**: Nearby sectors, city indexes, POI, lags, rolling stats
# 3. **Multiple Models**: CatBoost, LightGBM, Geometric baseline
# 4. **Smart Blending**: Weighted ensemble optimized on validation
# 5. **Conservative Post-processing**: Cap extremes, apply zero guard
#
# Current best: 0.56248 (geometric mean + seasonality)
# Target: 0.60+
